# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from datetime import datetime
from sklearn.neighbors import KNeighborsClassifier
from sklearn import cross_validation
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
# Out:
# /usr/local/lib/python2.7/dist-packages/pytz/__init__.py:29: UserWarning: Module dap was already imported from None, but /usr/lib/python2.7/dist-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %%
#List of all features available to us: 'POINT_X', 'POINT_Y', 'DATE', 'WEEK_DAY', 'MONTH', HOUR', 'TEMP, 'WIND', 'WIND_DIR', 'S_RAIN', 'S_SNOW', 'HUMIDITY', 'VISIBILITY', 'CLOUD COVER', 'PRECIP_INCHES', 'TEMP_LABELED', 'WIND_BINARY'  'YEAR'


data = pd.read_pickle('data/data_processed.pkl')
features = ['TEMP_LABELED', 'TEMP_LABELED','HOUR']
specific_data = data[features + ['CRIME_TYPE']]

X = np.array(specific_data)



### only use the code below if algorithm requires normalization before hand ###
'''
scaler = preprocessing.StandardScaler().fit(X)
X = scaler.transform(X)
'''

y = X[:,len(features)]

X= np.delete(X, len(features), 1)








predictions = []
actual = []
acc = []

kf = cross_validation.KFold(len(y), n_folds=10)

    
for train_index, test_index in kf:
        
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        
        
        clf = MultinomialNB()
        clf.fit(X_train, y_train)
        
        pred = clf.predict(X_test)
        accuracyDT = accuracy_score(y_test, pred)
        
        acc.append(accuracyDT)






print 'Accuracy', np.mean(acc)

print(metrics.classification_report(y_test, pred))
# Out:
# Accuracy 0.48572984273
#              precision    recall  f1-score   support
#
#       100.0       0.00      0.00      0.00       190
#       200.0       0.00      0.00      0.00       753
#       300.0       0.00      0.00      0.00      4158
#       400.0       0.00      0.00      0.00      4338
#       500.0       0.00      0.00      0.00      5462
#       600.0       0.48      1.00      0.65     18821
#       700.0       0.00      0.00      0.00      5184
#
# avg / total       0.23      0.48      0.32     38906

# %%
#########INSTANCE CREATION FOR PARTS 2 AND 3 #############

# %%
print data
# Out:
#           POINT_X    POINT_Y  HOUR  CRIME_TYPE  DATE  WEEK_DAY  MONTH  YEAR  \
# 0      -75.176999  40.052893    12         300  0505         2      5  2010
# 1      -74.966480  40.092613    12         600  0505         2      5  2010
# 2      -75.229249  39.922957    12         600  0505         2      5  2010
# 3      -75.188483  40.049717    12         500  0505         2      5  2010
# 4      -75.205490  39.965941    12         600  0505         2      5  2010
# 5      -75.153114  40.050414    12         700  0505         2      5  2010
# 6      -75.150014  40.038999    12         500  0505         2      5  2010
# 7      -75.164902  40.029913    12         500  0505         2      5  2010
# 8      -75.226981  39.998484    13         600  0331         2      3  2010
# 9      -75.171617  39.928379    13         600  0331         2      3  2010
# 10     -75.164569  39.918614    13         600  0331         2      3  2010
# ...

# %%
print float(data['CRIME_TYPE'].values.tolist().count(100))/float(len(data['CRIME_TYPE']))
print float(data['CRIME_TYPE'].values.tolist().count(200))/float(len(data['CRIME_TYPE']))
print float(data['CRIME_TYPE'].values.tolist().count(300))/float(len(data['CRIME_TYPE']))
print float(data['CRIME_TYPE'].values.tolist().count(400))/float(len(data['CRIME_TYPE']))
print float(data['CRIME_TYPE'].values.tolist().count(500))/float(len(data['CRIME_TYPE']))
print float(data['CRIME_TYPE'].values.tolist().count(600))/float(len(data['CRIME_TYPE']))
print float(data['CRIME_TYPE'].values.tolist().count(700))/float(len(data['CRIME_TYPE']))
print float(data['CRIME_TYPE'].values.tolist().count(800))/float(len(data['CRIME_TYPE']))
# Out:
# 0.00507371537845
# 0.0129207533979
# 0.102846832398
# 0.108516850698
# 0.139943556844
# 0.485729854214
# 0.144968437069
# 0.0
# 0.0
